# %% [markdown]
# <a href="https://colab.research.google.com/github/segravjf/python_practice/blob/main/replace_bad_data_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Replacing bad data with Pandas

# %% [markdown]
# Suppose you are given a dataframe, df, that contains various negative values. In the context of your work, negative values can be considered 'bad data'. Write a function in Python (using Pandas) that replaces these bad values with the group mean.

# %%
## Import modules
import pandas as pd
import numpy as np

# %%
## Create a fake dataset
ids = ['a','b','c','d','e','f','g']
values = [100,-90,45,77,-10, 0, 100]

df = pd.DataFrame({
    'id': ids,
    'value': values
})

df
# Out:
#   id  value
# 0  a    100
# 1  b    -90
# 2  c     45
# 3  d     77
# 4  e    -10
# 5  f      0
# 6  g    100

# %%
"""
Create a function that replaces negative values with the non-negative values group mean

Inputs: df, values column
Outputs: same df, but with values column fixed
"""
def replace_negatives(df, val_column):
  ## Remove negative values from the df
  nonnegs = df.loc[df[val_column] >= 0, :]
  ## Take the mean of the non-negative values
  group_mean = nonnegs[val_column].mean()
  ## Set the negative values as the group mean
  df.loc[df[val_column] < 0, [val_column]] = group_mean
  ## Return the new df
  return df

# %%
check = replace_negatives(df=df, val_column = 'value')

check
# Out:
#   id  value
# 0  a  100.0
# 1  b   64.4
# 2  c   45.0
# 3  d   77.0
# 4  e   64.4
# 5  f    0.0
# 6  g  100.0

# %%
## Check the work by getting the averages manually
sm = 100 + 45 + 77 + 0 + 100
mn = sm / 5.0
mn
# Out:
# 64.4
